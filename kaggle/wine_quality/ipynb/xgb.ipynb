# %%
'''
winequality-red.csvに対してxgboost, optunaを適用
'''

from functools import partial
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def div_max(df,column):
    df[column] = df[column]/df[column].max()
    return df

def preprocess(df):
    df = df.drop(['citric acid','free sulfur dioxide','fixed acidity','alcohol'],axis=1)
    df[target_column] = df[target_column] /10
    return df

def train(df,max_depth,learning_rate,num_round,gamma,min_childe_weigh,colsample_bytree,alpha,how_objective):
    train_x = df.drop(target_column,axis=1)
    train_y = df[target_column]
    dtrain = xgb.DMatrix(train_x,label=train_y)
    param = { 'max_depth':max_depth,'learning_rate':learning_rate,'objective':how_objective,'gamma':gamma,'min_childe_weigh':min_childe_weigh,'colsample_bytree':colsample_bytree,'alpha':alpha,'silent':1}
    bst = xgb.train(param,dtrain,num_round)
    return bst

def predict(bst,df):
    return bst.predict(xgb.DMatrix(df))*10

def objective(df, df_test, y, how_objective, trial):
    #目的関数
    max_depth = trial.suggest_int('max_depth',1,30)
    learning_rate = trial.suggest_uniform('learning_rate',0.0,1.0)
    round_num = trial.suggest_int('round_num',1,30)
    gamma = trial.suggest_uniform('gamma',0.0,10.0)
    colsample_bytree = trial.suggest_uniform('colsample_bytree',0.0,1.0)
    min_childe_weigh = trial.suggest_uniform('min_childe_weigh',0.0,10.0)
    alpha = trial.suggest_uniform('alpha',0.0,10.0)
    bst = train(df,max_depth,learning_rate,round_num,gamma,min_childe_weigh,colsample_bytree,alpha,how_objective)
    answer = predict(bst,df_test).round().astype(int)
    score = accuracy_score(answer,y.astype(int))
    return 1.0 - score

def main():
    global target_column
    df_original = pd.read_csv("/Users/pc1013/Desktop/first/XGBoost_optuna/df/winequality-red.csv")
    df = preprocess(df_original)
    (df_train, df_test) = train_test_split(df, test_size = 0.1, random_state = 666)
    y = df_test[target_column]*10
    df_test = df_test.drop(target_column,axis=1)
    
    how_objective = 'reg:logistic'
    #optunaの前処理
    obj_f = partial(objective, df_train, df_test, y, how_objective)
    #セッション作成
    study = optuna.create_study()
    #回数
    study.optimize(obj_f, n_trials=200)

    max_depth = study.best_params['max_depth']
    learning_rate = study.best_params['learning_rate']
    round_num = study.best_params['round_num']
    colsample_bytree = study.best_params['colsample_bytree']
    min_childe_weigh = study.best_params['min_childe_weigh']
    gamma = study.best_params['gamma']
    alpha = study.best_params['alpha']
        
    bst = train(df_train,max_depth,learning_rate,round_num,gamma,min_childe_weigh,colsample_bytree,alpha,how_objective)
    print('\nparams :',study.best_params)
    answer = predict(bst,df_train.drop(target_column,axis=1)).round().astype(int)
    print('train score :',accuracy_score(answer,df_train[target_column]*10))
    answer = predict(bst,df_test).round().astype(int)
    xgb.plot_importance(bst)
    print('test score :',accuracy_score(answer,y))

if __name__ == '__main__':
    target_column = 'quality'
    main()
# Out:
# [I 2019-02-22 13:33:01,427] Finished a trial resulted in value: 0.60625. Current best value is 0.60625 with parameters: {'max_depth': 22, 'learning_rate': 0.12177408715762372, 'round_num': 19, 'gamma': 5.167943576754813, 'colsample_bytree': 0.8806536715286986, 'min_childe_weigh': 2.5460538613597006, 'alpha': 5.544500809780422}.
# [I 2019-02-22 13:33:01,434] Finished a trial resulted in value: 0.55. Current best value is 0.55 with parameters: {'max_depth': 2, 'learning_rate': 0.2661112068999901, 'round_num': 3, 'gamma': 4.666904320398434, 'colsample_bytree': 0.8933883124601822, 'min_childe_weigh': 6.984570735095929, 'alpha': 2.0904243332875327}.
# [I 2019-02-22 13:33:01,442] Finished a trial resulted in value: 0.60625. Current best value is 0.55 with parameters: {'max_depth': 2, 'learning_rate': 0.2661112068999901, 'round_num': 3, 'gamma': 4.666904320398434, 'colsample_bytree': 0.8933883124601822, 'min_childe_weigh': 6.984570735095929, 'alpha': 2.0904243332875327}.
# [I 2019-02-22 13:33:01,470] Finished a trial resulted in value: 0.60625. Current best value is 0.55 with parameters: {'max_depth': 2, 'learning_rate': 0.2661112068999901, 'round_num': 3, 'gamma': 4.666904320398434, 'colsample_bytree': 0.8933883124601822, 'min_childe_weigh': 6.984570735095929, 'alpha': 2.0904243332875327}.
# [I 2019-02-22 13:33:01,482] Finished a trial resulted in value: 0.60625. Current best value is 0.55 with parameters: {'max_depth': 2, 'learning_rate': 0.2661112068999901, 'round_num': 3, 'gamma': 4.666904320398434, 'colsample_bytree': 0.8933883124601822, 'min_childe_weigh': 6.984570735095929, 'alpha': 2.0904243332875327}.
# [I 2019-02-22 13:33:01,500] Finished a trial resulted in value: 0.60625. Current best value is 0.55 with parameters: {'max_depth': 2, 'learning_rate': 0.2661112068999901, 'round_num': 3, 'gamma': 4.666904320398434, 'colsample_bytree': 0.8933883124601822, 'min_childe_weigh': 6.984570735095929, 'alpha': 2.0904243332875327}.
# [I 2019-02-22 13:33:01,513] Finished a trial resulted in value: 0.60625. Current best value is 0.55 with parameters: {'max_depth': 2, 'learning_rate': 0.2661112068999901, 'round_num': 3, 'gamma': 4.666904320398434, 'colsample_bytree': 0.8933883124601822, 'min_childe_weigh': 6.984570735095929, 'alpha': 2.0904243332875327}.
# [I 2019-02-22 13:33:01,527] Finished a trial resulted in value: 0.53125. Current best value is 0.53125 with parameters: {'max_depth': 16, 'learning_rate': 0.7615173869614632, 'round_num': 6, 'gamma': 0.9664219727702195, 'colsample_bytree': 0.5936707407067552, 'min_childe_weigh': 7.773213325698506, 'alpha': 3.2059938143497915}.
# [I 2019-02-22 13:33:01,547] Finished a trial resulted in value: 0.60625. Current best value is 0.53125 with parameters: {'max_depth': 16, 'learning_rate': 0.7615173869614632, 'round_num': 6, 'gamma': 0.9664219727702195, 'colsample_bytree': 0.5936707407067552, 'min_childe_weigh': 7.773213325698506, 'alpha': 3.2059938143497915}.
# [I 2019-02-22 13:33:01,573] Finished a trial resulted in value: 0.60625. Current best value is 0.53125 with parameters: {'max_depth': 16, 'learning_rate': 0.7615173869614632, 'round_num': 6, 'gamma': 0.9664219727702195, 'colsample_bytree': 0.5936707407067552, 'min_childe_weigh': 7.773213325698506, 'alpha': 3.2059938143497915}.
# [I 2019-02-22 13:33:01,595] Finished a trial resulted in value: 0.55. Current best value is 0.53125 with parameters: {'max_depth': 16, 'learning_rate': 0.7615173869614632, 'round_num': 6, 'gamma': 0.9664219727702195, 'colsample_bytree': 0.5936707407067552, 'min_childe_weigh': 7.773213325698506, 'alpha': 3.2059938143497915}.
# [I 2019-02-22 13:33:01,621] Finished a trial resulted in value: 0.525. Current best value is 0.525 with parameters: {'max_depth': 24, 'learning_rate': 0.7554341269733796, 'round_num': 2, 'gamma': 1.861320320803929, 'colsample_bytree': 0.6485874167342862, 'min_childe_weigh': 5.863000966437799, 'alpha': 4.617712335165676}.
# [I 2019-02-22 13:33:01,662] Finished a trial resulted in value: 0.525. Current best value is 0.525 with parameters: {'max_depth': 24, 'learning_rate': 0.7554341269733796, 'round_num': 2, 'gamma': 1.861320320803929, 'colsample_bytree': 0.6485874167342862, 'min_childe_weigh': 5.863000966437799, 'alpha': 4.617712335165676}.
# [I 2019-02-22 13:33:01,698] Finished a trial resulted in value: 0.55. Current best value is 0.525 with parameters: {'max_depth': 24, 'learning_rate': 0.7554341269733796, 'round_num': 2, 'gamma': 1.861320320803929, 'colsample_bytree': 0.6485874167342862, 'min_childe_weigh': 5.863000966437799, 'alpha': 4.617712335165676}.
# [I 2019-02-22 13:33:01,726] Finished a trial resulted in value: 0.525. Current best value is 0.525 with parameters: {'max_depth': 24, 'learning_rate': 0.7554341269733796, 'round_num': 2, 'gamma': 1.861320320803929, 'colsample_bytree': 0.6485874167342862, 'min_childe_weigh': 5.863000966437799, 'alpha': 4.617712335165676}.
# [I 2019-02-22 13:33:01,749] Finished a trial resulted in value: 0.60625. Current best value is 0.525 with parameters: {'max_depth': 24, 'learning_rate': 0.7554341269733796, 'round_num': 2, 'gamma': 1.861320320803929, 'colsample_bytree': 0.6485874167342862, 'min_childe_weigh': 5.863000966437799, 'alpha': 4.617712335165676}.
# [I 2019-02-22 13:33:01,788] Finished a trial resulted in value: 0.49375. Current best value is 0.49375 with parameters: {'max_depth': 20, 'learning_rate': 0.4136102549606821, 'round_num': 13, 'gamma': 1.5965723065789315, 'colsample_bytree': 0.7286254382920583, 'min_childe_weigh': 6.239751974897889, 'alpha': 0.9062301903880345}.
# [I 2019-02-22 13:33:01,829] Finished a trial resulted in value: 0.50625. Current best value is 0.49375 with parameters: {'max_depth': 20, 'learning_rate': 0.4136102549606821, 'round_num': 13, 'gamma': 1.5965723065789315, 'colsample_bytree': 0.7286254382920583, 'min_childe_weigh': 6.239751974897889, 'alpha': 0.9062301903880345}.
# [I 2019-02-22 13:33:01,884] Finished a trial resulted in value: 0.45625000000000004. Current best value is 0.45625000000000004 with parameters: {'max_depth': 19, 'learning_rate': 0.4602375536592449, 'round_num': 25, 'gamma': 0.20818891168389175, 'colsample_bytree': 0.7313412960955671, 'min_childe_weigh': 1.7702480118149455, 'alpha': 0.6302165045528305}.
# [I 2019-02-22 13:33:01,939] Finished a trial resulted in value: 0.4125. Current best value is 0.4125 with parameters: {'max_depth': 20, 'learning_rate': 0.2993040770400631, 'round_num': 22, 'gamma': 0.03949553465762867, 'colsample_bytree': 0.732068639493401, 'min_childe_weigh': 1.650425802835603, 'alpha': 0.7227189906133467}.
# [I 2019-02-22 13:33:02,026] Finished a trial resulted in value: 0.40625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,072] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,122] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,186] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,228] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,293] Finished a trial resulted in value: 0.42500000000000004. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,336] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,383] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,426] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,476] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,519] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,578] Finished a trial resulted in value: 0.5. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,622] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,662] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,731] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,775] Finished a trial resulted in value: 0.54375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,813] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,864] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,912] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:02,968] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,017] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,062] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,114] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,165] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,208] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,250] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,297] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,351] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,400] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,450] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,496] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,556] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,601] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,671] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,759] Finished a trial resulted in value: 0.45625000000000004. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,813] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,868] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,917] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:03,984] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,041] Finished a trial resulted in value: 0.48124999999999996. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,105] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,170] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,231] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,300] Finished a trial resulted in value: 0.49375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,359] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,448] Finished a trial resulted in value: 0.41874999999999996. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,512] Finished a trial resulted in value: 0.48750000000000004. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,569] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,658] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,725] Finished a trial resulted in value: 0.49375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,787] Finished a trial resulted in value: 0.50625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,853] Finished a trial resulted in value: 0.49375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,916] Finished a trial resulted in value: 0.45625000000000004. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:04,997] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,070] Finished a trial resulted in value: 0.51875. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,148] Finished a trial resulted in value: 0.49375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,225] Finished a trial resulted in value: 0.50625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,291] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,361] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,437] Finished a trial resulted in value: 0.43125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,506] Finished a trial resulted in value: 0.50625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,581] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,663] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,748] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,817] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,889] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:05,963] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,046] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,111] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,186] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,260] Finished a trial resulted in value: 0.49375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,343] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,421] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,491] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,564] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,643] Finished a trial resulted in value: 0.51875. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,733] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,820] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,898] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:06,981] Finished a trial resulted in value: 0.50625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,058] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,161] Finished a trial resulted in value: 0.50625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,250] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,330] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,418] Finished a trial resulted in value: 0.50625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,503] Finished a trial resulted in value: 0.46875. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,599] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,680] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,756] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,836] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,913] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:07,996] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,099] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,185] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,303] Finished a trial resulted in value: 0.51875. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,386] Finished a trial resulted in value: 0.48124999999999996. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,466] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,553] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,641] Finished a trial resulted in value: 0.44375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,735] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,819] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:08,905] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,002] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,085] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,172] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,273] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,382] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,483] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,588] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,673] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,771] Finished a trial resulted in value: 0.5. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,872] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:09,990] Finished a trial resulted in value: 0.5375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,112] Finished a trial resulted in value: 0.475. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,216] Finished a trial resulted in value: 0.4625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,305] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,399] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,498] Finished a trial resulted in value: 0.525. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,602] Finished a trial resulted in value: 0.55. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,717] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,818] Finished a trial resulted in value: 0.5125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:10,930] Finished a trial resulted in value: 0.4375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:11,036] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:11,139] Finished a trial resulted in value: 0.60625. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# ...
# [I 2019-02-22 13:33:12,501] Finished a trial resulted in value: 0.53125. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:12,628] Finished a trial resulted in value: 0.5375. Current best value is 0.40625 with parameters: {'max_depth': 19, 'learning_rate': 0.2980996905382223, 'round_num': 24, 'gamma': 0.026952498047674047, 'colsample_bytree': 0.981084293726486, 'min_childe_weigh': 1.8863444637141698, 'alpha': 0.006466390734996885}.
# [I 2019-02-22 13:33:12,755] Finished a trial resulted in value: 0.38749999999999996. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:12,875] Finished a trial resulted in value: 0.40625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:12,985] Finished a trial resulted in value: 0.5. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,092] Finished a trial resulted in value: 0.55. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,225] Finished a trial resulted in value: 0.50625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,338] Finished a trial resulted in value: 0.4625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,455] Finished a trial resulted in value: 0.53125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,574] Finished a trial resulted in value: 0.525. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,696] Finished a trial resulted in value: 0.50625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,820] Finished a trial resulted in value: 0.48124999999999996. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:13,925] Finished a trial resulted in value: 0.53125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,057] Finished a trial resulted in value: 0.525. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,180] Finished a trial resulted in value: 0.5125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,302] Finished a trial resulted in value: 0.55. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,431] Finished a trial resulted in value: 0.4625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,576] Finished a trial resulted in value: 0.60625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,703] Finished a trial resulted in value: 0.60625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,814] Finished a trial resulted in value: 0.5375. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:14,931] Finished a trial resulted in value: 0.49375. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,058] Finished a trial resulted in value: 0.55. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,179] Finished a trial resulted in value: 0.53125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,311] Finished a trial resulted in value: 0.5125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,428] Finished a trial resulted in value: 0.60625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,574] Finished a trial resulted in value: 0.44999999999999996. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,718] Finished a trial resulted in value: 0.51875. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,848] Finished a trial resulted in value: 0.60625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:15,969] Finished a trial resulted in value: 0.55. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:16,095] Finished a trial resulted in value: 0.53125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:16,253] Finished a trial resulted in value: 0.46875. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:16,384] Finished a trial resulted in value: 0.53125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:16,531] Finished a trial resulted in value: 0.5. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:16,666] Finished a trial resulted in value: 0.51875. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:16,789] Finished a trial resulted in value: 0.525. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:16,924] Finished a trial resulted in value: 0.53125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:17,048] Finished a trial resulted in value: 0.48750000000000004. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:17,185] Finished a trial resulted in value: 0.5. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:17,307] Finished a trial resulted in value: 0.5125. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:17,453] Finished a trial resulted in value: 0.60625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:17,594] Finished a trial resulted in value: 0.60625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:17,733] Finished a trial resulted in value: 0.4375. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:17,870] Finished a trial resulted in value: 0.51875. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:18,021] Finished a trial resulted in value: 0.60625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# [I 2019-02-22 13:33:18,153] Finished a trial resulted in value: 0.50625. Current best value is 0.38749999999999996 with parameters: {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}.
# params : {'max_depth': 29, 'learning_rate': 0.28757208290026653, 'round_num': 26, 'gamma': 0.020956024629465553, 'colsample_bytree': 0.6159882657868399, 'min_childe_weigh': 3.985847798632851, 'alpha': 0.43091254386417777}
# train score : 0.7275886031966643
# test score : 0.6125

# %%
'''
[16:22:00] src/objective/objective.cc:21: Objective candidate: binary:hinge
[16:22:00] src/objective/objective.cc:21: Objective candidate: multi:softmax
[16:22:00] src/objective/objective.cc:21: Objective candidate: multi:softprob
[16:22:00] src/objective/objective.cc:21: Objective candidate: rank:pairwise
[16:22:00] src/objective/objective.cc:21: Objective candidate: rank:ndcg
[16:22:00] src/objective/objective.cc:21: Objective candidate: rank:map
[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:linear
[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:logistic
[16:22:00] src/objective/objective.cc:21: Objective candidate: binary:logistic
[16:22:00] src/objective/objective.cc:21: Objective candidate: binary:logitraw
[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:reg:linear
[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:reg:logistic
[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:binary:logistic
[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:binary:logitraw
[16:22:00] src/objective/objective.cc:21: Objective candidate: count:poisson
[16:22:00] src/objective/objective.cc:21: Objective candidate: survival:cox
[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:gamma
[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:tweedie
'''
# Out:
# '\n[16:22:00] src/objective/objective.cc:21: Objective candidate: binary:hinge\n[16:22:00] src/objective/objective.cc:21: Objective candidate: multi:softmax\n[16:22:00] src/objective/objective.cc:21: Objective candidate: multi:softprob\n[16:22:00] src/objective/objective.cc:21: Objective candidate: rank:pairwise\n[16:22:00] src/objective/objective.cc:21: Objective candidate: rank:ndcg\n[16:22:00] src/objective/objective.cc:21: Objective candidate: rank:map\n[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:linear\n[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:logistic\n[16:22:00] src/objective/objective.cc:21: Objective candidate: binary:logistic\n[16:22:00] src/objective/objective.cc:21: Objective candidate: binary:logitraw\n[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:reg:linear\n[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:reg:logistic\n[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:binary:logistic\n[16:22:00] src/objective/objective.cc:21: Objective candidate: gpu:binary:logitraw\n[16:22:00] src/objective/objective.cc:21: Objective candidate: count:poisson\n[16:22:00] src/objective/objective.cc:21: Objective candidate: survival:cox\n[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:gamma\n[16:22:00] src/objective/objective.cc:21: Objective candidate: reg:tweedie\n'

# %%
##############################################################################################

# %%
'''
適当なパラメータ
'''

from functools import partial
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def div_max(df,column):
    df[column] = df[column]/df[column].max()
    return df

def preprocess(df):
    df[target_column] = df[target_column] /10
    return df

def train(df,max_depth,learning_rate,num_round,how_objective):
    train_x = df.drop(target_column,axis=1)
    train_y = df[target_column]
    dtrain = xgb.DMatrix(train_x,label=train_y)
    param = { 'max_depth':max_depth,'learning_rate':learning_rate,'objective':how_objective,'silent':1}
    bst = xgb.train(param,dtrain,num_round)
    return bst

def predict(bst,df):
    return bst.predict(xgb.DMatrix(df))*10

def objective(df, df_test, y, how_objective, trial):
    #目的関数
    max_depth = trial.suggest_int('max_depth',1,30)
    learning_rate = trial.suggest_uniform('learning_rate',0.0,1.0)
    round_num = trial.suggest_int('round_num',1,30)
    bst = train(df,max_depth,learning_rate,round_num,how_objective)
    answer = predict(bst,df_test).round().astype(int)
    score = accuracy_score(answer,y.astype(int))
    return 1.0 - score

def main():
    global target_column
    df_original = pd.read_csv("/Users/pc1013/Desktop/first/XGBoost_optuna/df/winequality-red.csv")
    df = preprocess(df_original)
    (df_train, df_test) = train_test_split(df, test_size = 0.1, random_state = 666)
    y = df_test[target_column]*10
    df_test = df_test.drop(target_column,axis=1)
    
    how_objective = 'reg:linear'

    max_depth = 6
    learning_rate = 0.1
    round_num = 10
    
    bst = train(df_train,max_depth,learning_rate,round_num,how_objective)
    answer = predict(bst,df_train.drop(target_column,axis=1)).round().astype(int) 
    print('train score :',accuracy_score(answer,df_train[target_column]*10))
    answer = predict(bst,df_test).round().astype(int)
    print('test score :',accuracy_score(answer,y))
    xgb.plot_importance(bst)

if __name__ == '__main__':
    target_column = 'quality'
    main()

# %%
'''
winequality-red.csvに対してxgboost, optunaを適用
'''

from functools import partial
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def div_max(df,column):
    df[column] = df[column]/df[column].max()
    return df

def preprocess(df):
    df[target_column] = df[target_column] /10
    return df

def train(df,max_depth,learning_rate,num_round,how_objective):
    train_x = df.drop(target_column,axis=1)
    train_y = df[target_column]
    dtrain = xgb.DMatrix(train_x,label=train_y)
    param = { 'max_depth':max_depth,'learning_rate':learning_rate,'objective':how_objective,'silent':1}
    bst = xgb.train(param,dtrain,num_round)
    return bst

def predict(bst,df):
    return bst.predict(xgb.DMatrix(df))*10

def objective(df, df_test, y, how_objective, trial):
    #目的関数
    max_depth = trial.suggest_int('max_depth',1,30)
    learning_rate = trial.suggest_uniform('learning_rate',0.0,1.0)
    round_num = trial.suggest_int('round_num',1,30)
    bst = train(df,max_depth,learning_rate,round_num,how_objective)
    answer = predict(bst,df_test).round().astype(int)
    score = accuracy_score(answer,y.astype(int))
    return 1.0 - score

def main():
    global target_column
    df_original = pd.read_csv("/Users/pc1013/Desktop/first/XGBoost_optuna/df/winequality-red.csv")
    df = preprocess(df_original)
    (df_train, df_test) = train_test_split(df, test_size = 0.1, random_state = 666)
    y = df_test[target_column]*10
    df_test = df_test.drop(target_column,axis=1)
    
    how_objective = 'reg:linear'
    #optunaの前処理
    obj_f = partial(objective, df_train, df_test, y, how_objective)
    #セッション作成
    study = optuna.create_study()
    #回数
    study.optimize(obj_f, n_trials=100)

    max_depth = study.best_params['max_depth']
    learning_rate = study.best_params['learning_rate']
    round_num = study.best_params['round_num']
    
    bst = train(df_train,max_depth,learning_rate,round_num,how_objective)
    print('\nparams :',study.best_params)
    answer = predict(bst,df_train.drop(target_column,axis=1)).round().astype(int)
    print('train score :',accuracy_score(answer,df_train[target_column]*10))
    answer = predict(bst,df_test).round().astype(int)
    xgb.plot_importance(bst)
    print('test score :',accuracy_score(answer,y))

if __name__ == '__main__':
    target_column = 'quality'
    main()
